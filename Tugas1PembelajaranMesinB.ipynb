# %% [markdown]
# <a href="https://colab.research.google.com/github/AlifGolo/PembelajaranMesinB/blob/main/Tugas1PembelajaranMesinB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Alif Ananda Athallah
#H081221018 (Ilmu Aktuaria)
#Pembelajaran Mesin B
import pandas as pd

# %%
nama_file = '/content/drive/MyDrive/Pembelajaran Mesin B/Food Waste data and research - by country.csv'

# %%
df = pd.read_csv(nama_file)

# %%
df
# Out:
#                         Country  combined figures (kg/capita/year)  \
# 0                   Afghanistan                                126
# 1                       Albania                                127
# 2                       Algeria                                135
# 3                       Andorra                                123
# 4                        Angola                                144
# ..                          ...                                ...
# 209  Venezuela (Boliv. Rep. of)                                116
# 210                    Viet Nam                                120
# 211                       Yemen                                148
# 212                      Zambia                                122
# 213                    Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                     82                           3109153
# ...

# %%
df.head(4)
# Out:
#        Country  combined figures (kg/capita/year)  \
# 0  Afghanistan                                126
# 1      Albania                                127
# 2      Algeria                                135
# 3      Andorra                                123
#
#    Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                   82                           3109153
# 1                                   83                            238492
# 2                                   91                           3918529
# 3                                   84                              6497
#
#    Retail estimate (kg/capita/year)  Retail estimate (tonnes/year)  \
# 0                                16                         594982
# 1                                16                          45058
# 2                                16                         673360
# 3                                13                            988
#
# ...

# %%
df.dtypes
# Out:
# Country                                   object
# combined figures (kg/capita/year)          int64
# Household estimate (kg/capita/year)        int64
# Household estimate (tonnes/year)           int64
# Retail estimate (kg/capita/year)           int64
# Retail estimate (tonnes/year)              int64
# Food service estimate (kg/capita/year)     int64
# Food service estimate (tonnes/year)        int64
# Confidence in estimate                    object
# M49 code                                   int64
# Region                                    object
# Source                                    object
# dtype: object

# %%
dfnoconfidence = df.drop(df.columns[9],axis=1)

# %%
dfnoconfidence
#yang terhapus malah m49 code, bukan confidence in estimate
# Out:
#                         Country  combined figures (kg/capita/year)  \
# 0                   Afghanistan                                126
# 1                       Albania                                127
# 2                       Algeria                                135
# 3                       Andorra                                123
# 4                        Angola                                144
# ..                          ...                                ...
# 209  Venezuela (Boliv. Rep. of)                                116
# 210                    Viet Nam                                120
# 211                       Yemen                                148
# 212                      Zambia                                122
# 213                    Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                     82                           3109153
# ...

# %%
dfregion = df.drop(df.columns[10],axis=1)

# %%
dfregion
#ggsudahbenar
# Out:
#                         Country  combined figures (kg/capita/year)  \
# 0                   Afghanistan                                126
# 1                       Albania                                127
# 2                       Algeria                                135
# 3                       Andorra                                123
# 4                        Angola                                144
# ..                          ...                                ...
# 209  Venezuela (Boliv. Rep. of)                                116
# 210                    Viet Nam                                120
# 211                       Yemen                                148
# 212                      Zambia                                122
# 213                    Zimbabwe                                144
#
#      Household estimate (kg/capita/year)  Household estimate (tonnes/year)  \
# 0                                     82                           3109153
# ...

# %%
df.describe()
# Out:
#        combined figures (kg/capita/year)  Household estimate (kg/capita/year)  \
# count                         214.000000                           214.000000
# mean                          126.794393                            84.294393
# std                            22.157879                            18.313705
# min                            61.000000                            33.000000
# 25%                           115.000000                            74.000000
# 50%                           123.000000                            80.000000
# 75%                           137.750000                            95.000000
# max                           260.000000                           189.000000
#
#        Household estimate (tonnes/year)  Retail estimate (kg/capita/year)  \
# count                      2.140000e+02                        214.000000
# mean                       2.658896e+06                         15.116822
# ...

# %%
df.loc[:,"M49 code":].corr()
# Out:
# <ipython-input-21-3edb0777a6e5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.loc[:,"M49 code":].corr()
#           M49 code
# M49 code       1.0

# %%
df.loc[:,"combined figures (kg/capita/year)":].corr()
# Out:
# <ipython-input-23-a2e620d6328a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.loc[:,"combined figures (kg/capita/year)":].corr()
#                                         combined figures (kg/capita/year)  \
# combined figures (kg/capita/year)                                1.000000
# Household estimate (kg/capita/year)                              0.871324
# Household estimate (tonnes/year)                                 0.052237
# Retail estimate (kg/capita/year)                                 0.555106
# Retail estimate (tonnes/year)                                   -0.017693
# Food service estimate (kg/capita/year)                           0.460778
# Food service estimate (tonnes/year)                             -0.015442
# M49 code                                                         0.044763
# ...

# %%
df.plot(kind='scatter', x='combined figures (kg/capita/year)', y='Household estimate (kg/capita/year)', s=32, alpha=1)
df.gca().spines[['top', 'right',]].set_visible(false)
#nyerah
